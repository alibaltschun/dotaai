# %%
from fastai.vision import *

# %%
path = './research/dataset/dataset/select_hero'

# %%
data = ImageDataBunch.from_folder(path, size=64,)
# Out:
# /home/baltschun/anaconda3/lib/python3.7/site-packages/fastai/data_block.py:537: UserWarning: You are labelling your items with CategoryList.
# Your valid set contained the following unknown labels, the corresponding items have been discarded.
# unselecting
#   if getattr(ds, 'warn', False): warn(ds.warn)

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy,)

# %%
learn.fit(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.929179</td>
#       <td>0.966461</td>
#       <td>0.764796</td>
#       <td>00:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.647793</td>
#       <td>0.075338</td>
#       <td>0.976941</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.420666</td>
#       <td>0.020120</td>
#       <td>0.994620</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.308685</td>
#       <td>0.002187</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.267614</td>
#       <td>0.001668</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.236514</td>
#       <td>0.000634</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.210038</td>
#       <td>0.000626</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.192338</td>
#       <td>0.000583</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.173950</td>
#       <td>0.000503</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.186218</td>
#       <td>0.000759</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.155448</td>
#       <td>0.000392</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export()

# %%
learn.fit(10)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.00% [1/10 00:31<04:44]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.145310</td>
#       <td>0.000427</td>
#       <td>1.000000</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='443' class='' max='2011', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.03% [443/2011 00:07<00:26 0.1206]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-3371a2bf699b> in <module>
# ----> 1 learn.fit(10)
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
# ---> 35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/callback.py in step(self)
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      56             self.set_val('weight_decay', listify(0, self._wd))
# ---> 57         self.opt.step()
#      58
#      59     def zero_grad(self)->None:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     101                     denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     102                 else:
# --> 103                     denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     104
#     105                 step_size = group['lr'] / bias_correction1
#
# KeyboardInterrupt:

# %%
learn.export()

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(9, figsize=(12,12))
