# %%
from fastai.vision import *

# %%
path = './research/dataset/dataset/team'

# %%
data = ImageDataBunch.from_folder(path, size=32,)

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy,)

# %%
learn.fit(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.119999</td>
#       <td>0.004188</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export()

# %%
learn.fit(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.384681</td>
#       <td>0.200618</td>
#       <td>0.900000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.209781</td>
#       <td>0.097965</td>
#       <td>0.962500</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.158786</td>
#       <td>0.019478</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export()

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(9, figsize=(12,12))
